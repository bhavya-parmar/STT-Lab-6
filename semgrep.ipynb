# %% [markdown]
# # Using Semgrep CLI

# %%
! pip install semgrep
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 31.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.5/158.5 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 7.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.7/100.7 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.9/131.9 kB 5.2 MB/s eta 0:00:00
# ...

# %%
! semgrep login

# cleared cell output for token privacy

# %%
! git clone https://github.com/androguard/androguard.git
# Out:
# Cloning into 'androguard'...
# remote: Enumerating objects: 20988, done.
# remote: Counting objects: 100% (788/788), done.
# remote: Compressing objects: 100% (231/231), done.
# remote: Total 20988 (delta 617), reused 580 (delta 556), pack-reused 20200 (from 4)
# Receiving objects: 100% (20988/20988), 107.95 MiB | 32.22 MiB/s, done.
# Resolving deltas: 100% (14536/14536), done.

# %%
! cd /kaggle/working/androguard

# %%
! semgrep scan --config "p/default" --json-output=semgrep_androguard.json
# Out:
# ┌──── ○○○ ────┐
# │ Semgrep CLI │
# └─────────────┘
#
# METRICS: Using configs from the Registry (like --config=p/ci) reports pseudonymous rule metrics to semgrep.dev.
# To disable Registry rule metrics, use "--metrics=off".
# When using configs only from local files (like --config=xyz.yml) metrics are sent only when the user is logged in.
#
# More information: https://semgrep.dev/docs/metrics
#
#
# Scanning 156 files (only git-tracked) with 2452 Code rules:
#
#   CODE RULES
#
#   Language      Rules   Files          Origin      Rules
#  ─────────────────────────────        ───────────────────
#   <multilang>      48     156          Pro rules    1390
#   python          879      51          Community    1062
#   json              4      40
#   js              324      30
#   yaml             31       7
#
#
#   SUPPLY CHAIN RULES
#
#   💎 Run `semgrep ci` to find dependency
#      vulnerabilities and advanced cross-file findings.
#
#
#   PROGRESS
#
# ...

# %%
! git clone https://github.com/vega/altair.git
# Out:
# Cloning into 'altair'...
# remote: Enumerating objects: 32555, done.
# remote: Counting objects: 100% (566/566), done.
# remote: Compressing objects: 100% (226/226), done.
# remote: Total 32555 (delta 424), reused 371 (delta 340), pack-reused 31989 (from 3)
# Receiving objects: 100% (32555/32555), 46.33 MiB | 27.45 MiB/s, done.
# Resolving deltas: 100% (23669/23669), done.

# %%
! cd /kaggle/working/altair

# %%
! semgrep scan --config "p/default" --json-output=semgrep_altair.json
# Out:
# ┌──── ○○○ ────┐
# │ Semgrep CLI │
# └─────────────┘
#
# METRICS: Using configs from the Registry (like --config=p/ci) reports pseudonymous rule metrics to semgrep.dev.
# To disable Registry rule metrics, use "--metrics=off".
# When using configs only from local files (like --config=xyz.yml) metrics are sent only when the user is logged in.
#
# More information: https://semgrep.dev/docs/metrics
#
#
# Scanning 209 files (only git-tracked) with 2452 Code rules:
#
#   CODE RULES
#
#   Language      Rules   Files          Origin      Rules
#  ─────────────────────────────        ───────────────────
#   <multilang>      61     209          Pro rules    1390
#   python          879      79          Community    1062
#   yaml             31      10
#   html              1       3
#   js              324       1
#   json              4       1
#
#
#   SUPPLY CHAIN RULES
#
#   💎 Run `semgrep ci` to find dependency
#      vulnerabilities and advanced cross-file findings.
#
#
#   PROGRESS
#
# ...

# %%
! git clone https://github.com/agno-agi/agno.git
# Out:
# Cloning into 'agno'...
# remote: Enumerating objects: 111609, done.
# remote: Counting objects: 100% (1398/1398), done.
# remote: Compressing objects: 100% (776/776), done.
# remote: Total 111609 (delta 1093), reused 625 (delta 622), pack-reused 110211 (from 4)
# Receiving objects: 100% (111609/111609), 232.48 MiB | 25.52 MiB/s, done.
# Resolving deltas: 100% (70930/70930), done.

# %%
! cd /kaggle/working/agno

# %%
! semgrep scan --config "p/default" --json-output=semgrep_agno.json
# Out:
# ┌──── ○○○ ────┐
# │ Semgrep CLI │
# └─────────────┘
#
# METRICS: Using configs from the Registry (like --config=p/ci) reports pseudonymous rule metrics to semgrep.dev.
# To disable Registry rule metrics, use "--metrics=off".
# When using configs only from local files (like --config=xyz.yml) metrics are sent only when the user is logged in.
#
# More information: https://semgrep.dev/docs/metrics
#
#
# Scanning 2707 files (only git-tracked) with 2452 Code rules:
#
#   CODE RULES
#
#   Language      Rules   Files          Origin      Rules
#  ─────────────────────────────        ───────────────────
#   <multilang>      48    2707          Pro rules    1390
#   python          879    2412          Community    1062
#   bash              4      49
#   yaml             31      13
#   json              4       5
#
#
#   SUPPLY CHAIN RULES
#
#   💎 Run `semgrep ci` to find dependency
#      vulnerabilities and advanced cross-file findings.
#
#
#   PROGRESS
#
# ...
